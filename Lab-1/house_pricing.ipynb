# %% [markdown]
# # Kaggle ML House Pricing

# %% [markdown]
# - **Dataset:** [Kaggle MelBourne-Housing](https://www.kaggle.com/datasets/dansbecker/melbourne-housing-snapshot)
# - **ML Task:** Predict House Pricing
#
# ![1.png](attachment:1d24e11f-46bb-4772-b140-2bddb76b4b8d.png)

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd

# %%
melbourne_file_path = './Lab-1/data/melb_data.csv'

melbourne_df = # TO-DO: read dataset into pandas dataframe

# TO-DO: print summary description of the dataset
# ___

# %%
melbourne_df.columns

# %% [markdown]
# ## Data Cleaning

# %%
melbourne_df = # TO-DO: drop any cells with NA

# %% [markdown]
# ## Choose The Prediction Target and Features

# %%
y = # TO-DO: set y to store price column

# %%
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
X = # TO-DO: set X to store selected features data

# %%
# TO-DO: print first 5 columns of X

# %%
# TO-DO: print summary description of X

# %% [markdown]
# ## Split Train & Validate Datasets

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, validate_X, train_y, validate_y = train_test_split(X, y, random_state=0)

# %%
train_X.describe()

# %%
validate_X.describe()

# %%
train_y.describe()

# %%
validate_y.describe()

# %% [markdown]
# ## Modeling

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
melbourne_model = DecisionTreeRegressor(random_state=1)

# TO-DO fit the model using X and y

# %%
type(melbourne_model)

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(melbourne_model.predict(X.head()))

# %% [markdown]
# ## Model Validation
#
# Using Mean Absolute Error (MAE)
#
# Error = Actual - Predicted

# %%
from sklearn.metrics import mean_absolute_error

# %%
predicted_home_prices = # TO-DO: predict using validation dataset

# TO-DO: calculate the mean-absolute-error

# %% [markdown]
# ## Compare Using Different Model (Random Forest)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# TO-DO: using same data: train, predict, and validate using Random forest model
